# %%
import os

# Define the directory
output_dir = "../outputs"

# Ensure the directory exists
if os.path.exists(output_dir):
    # Loop through all files in the directory
    for file_name in os.listdir(output_dir):
        file_path = os.path.join(output_dir, file_name)

        # Check if it's a file before deleting
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted: {file_path}")
    print("All files in '../outputs' have been deleted.")
else:
    print("The directory '../outputs' does not exist.")
# Out:
# Deleted: ../outputs/TWE GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/^AXJO_returns.png
# Deleted: ../outputs/IEL_interested_ticker_raw_stats.png
# Deleted: ../outputs/0700_D_E_comparison.png
# Deleted: ../outputs/NVX_stock_splits_over_time.png
# Deleted: ../outputs/TWE_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/AGL GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/TYR_RoA_comparison.png
# Deleted: ../outputs/VEVE.L_returns.png
# Deleted: ../outputs/VT_dividends_and_change_over_time.png
# Deleted: ../outputs/^AORD_returns.png
# Deleted: ../outputs/IEL_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/000001_close_price.png
# Deleted: ../outputs/0700_P_E_comparison.png
# Deleted: ../outputs/NVDA_dividends_and_change_over_time.png
# Deleted: ../outputs/AAPL_key_ticker_stats_table.png
# Deleted: ../outputs/DPZ_P_B_comparison.png
# Deleted: ../outputs/CSL GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/TYR_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/DPZ_returns.png
# Deleted: ../outputs/SPY_correlation_matrix.png
# Deleted: ../outputs/IEL_comparative_returns.png
# Deleted: ../outputs/^AXJO_dividends_and_change_over_time.png
# Deleted: ../outputs/ACWI_dividends_and_change_over_time.png
# Deleted: ../outputs/0700_comparative_returns.png
# Deleted: ../outputs/DIA_correlation_matrix.png
# Deleted: ../outputs/AAPL_correlation_matrix.png
# Deleted: ../outputs/ACWI_close_price.png
# Deleted: ../outputs/STW_correlation_matrix.png
# Deleted: ../outputs/TWE_P_B_comparison.png
# Deleted: ../outputs/0700_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVDA_comparative_returns.png
# Deleted: ../outputs/601211_comparative_returns.png
# Deleted: ../outputs/TWE_dividends_over_time.png
# Deleted: ../outputs/TWE GICS I.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/TYR_stock_splits_over_time.png
# Deleted: ../outputs/601211_close_price.png
# Deleted: ../outputs/601211_returns.png
# Deleted: ../outputs/TWE GICS I.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/IEL_RoA_comparison.png
# Deleted: ../outputs/000001_RoE_comparison.png
# Deleted: ../outputs/DPZ_D_E_comparison.png
# Deleted: ../outputs/AAPL_dividends_over_time.png
# Deleted: ../outputs/000300.SS_returns.png
# Deleted: ../outputs/IEL_correlation_matrix.png
# Deleted: ../outputs/AGL_key_ticker_stats_table.png
# Deleted: ../outputs/000001_Current Ratio_comparison.png
# Deleted: ../outputs/TWE_correlation_matrix.png
# Deleted: ../outputs/DPZ_P_E_comparison.png
# Deleted: ../outputs/CSL_interested_ticker_raw_stats.png
# Deleted: ../outputs/0700_P_B_comparison.png
# Deleted: ../outputs/VEVE_returns.png
# Deleted: ../outputs/0700_returns.png
# Deleted: ../outputs/000001_Free Cash Flow_comparison.png
# Deleted: ../outputs/DPZ_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/DPZ_dividends_and_change_over_time.png
# Deleted: ../outputs/AGL_Free Cash Flow_comparison.png
# Deleted: ../outputs/NVX_Net Income Margin_comparison.png
# Deleted: ../outputs/TWE_D_E_comparison.png
# Deleted: ../outputs/AGL_dividends_over_time.png
# Deleted: ../outputs/AAPL_RoE_comparison.png
# Deleted: ../outputs/AGL_DPS_comparison.png
# Deleted: ../outputs/NVDA_RoE_comparison.png
# Deleted: ../outputs/DPZ_Dividend Yield_comparison.png
# Deleted: ../outputs/0700_stock_splits_over_time.png
# Deleted: ../outputs/TWE_P_E_comparison.png
# Deleted: ../outputs/000001_interested_ticker_raw_stats.png
# Deleted: ../outputs/NVX_interested_ticker_raw_stats.png
# Deleted: ../outputs/601211_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/0700_RoE_comparison.png
# Deleted: ../outputs/TWE_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/VAS_key_ticker_stats_table.png
# Deleted: ../outputs/EFA_stock_splits_over_time.png
# Deleted: ../outputs/STW_comparative_returns.png
# Deleted: ../outputs/AGL_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/000001_P_B_comparison.png
# Deleted: ../outputs/CSL GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/CSL_key_ticker_stats_table.png
# Deleted: ../outputs/NVDA_Dividend Yield_comparison.png
# Deleted: ../outputs/NVX_comparative_returns.png
# Deleted: ../outputs/AGL GICS I.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/TWE_Current Ratio_comparison.png
# Deleted: ../outputs/QQQ_correlation_matrix.png
# Deleted: ../outputs/NVDA_P_B_comparison.png
# Deleted: ../outputs/^AXJO_key_ticker_stats_table.png
# Deleted: ../outputs/DPZ_key_ticker_stats_table.png
# Deleted: ../outputs/000001_comparative_returns.png
# Deleted: ../outputs/AAPL_P_B_comparison.png
# Deleted: ../outputs/TWE_close_price.png
# Deleted: ../outputs/^AXJO_comparative_returns.png
# Deleted: ../outputs/CSL_Free Cash Flow_comparison.png
# Deleted: ../outputs/TYR_correlation_matrix.png
# Deleted: ../outputs/000001_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/VEVE.L_key_ticker_stats_table.png
# Deleted: ../outputs/DPZ_Current Ratio_comparison.png
# Deleted: ../outputs/ACWI_stock_splits_over_time.png
# Deleted: ../outputs/NVDA_correlation_matrix.png
# Deleted: ../outputs/TYR_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVX_DPS_comparison.png
# Deleted: ../outputs/000001_D_E_comparison.png
# Deleted: ../outputs/IEL_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/IEL_returns.png
# Deleted: ../outputs/DPZ_RoE_comparison.png
# Deleted: ../outputs/VAS_comparative_returns.png
# Deleted: ../outputs/AGL GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/CSL_dividends_and_change_over_time.png
# Deleted: ../outputs/AGL_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVX_Dividend Yield_comparison.png
# Deleted: ../outputs/000001_P_E_comparison.png
# Deleted: ../outputs/601211_DPS_comparison.png
# Deleted: ../outputs/TYR_Current Ratio_comparison.png
# Deleted: ../outputs/NVDA_P_E_comparison.png
# Deleted: ../outputs/TWE_RoE_comparison.png
# Deleted: ../outputs/CSL_RoA_comparison.png
# Deleted: ../outputs/NVX_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/AAPL_D_E_comparison.png
# Deleted: ../outputs/TWE GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/NVDA_D_E_comparison.png
# Deleted: ../outputs/NVDA_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/TWE_Free Cash Flow_comparison.png
# Deleted: ../outputs/CSL_Current Ratio_comparison.png
# Deleted: ../outputs/AAPL_P_E_comparison.png
# Deleted: ../outputs/TYR_dividends_over_time.png
# Deleted: ../outputs/NVX_Net Profit Margin_comparison.png
# Deleted: ../outputs/AGL GICS I.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/CSL_P_E_comparison.png
# Deleted: ../outputs/AGL_interested_ticker_raw_stats.png
# Deleted: ../outputs/TYR_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/DIA_key_ticker_stats_table.png
# Deleted: ../outputs/AAPL_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVDA_RoA_comparison.png
# Deleted: ../outputs/IEL_Dividend Yield_comparison.png
# Deleted: ../outputs/VEVE.L_comparative_returns.png
# Deleted: ../outputs/AAPL_RoA_comparison.png
# Deleted: ../outputs/EFA_close_price.png
# Deleted: ../outputs/CSL_D_E_comparison.png
# Deleted: ../outputs/NVX_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/0700_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/TYR_Free Cash Flow_comparison.png
# Deleted: ../outputs/NVX GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/000001_stock_splits_over_time.png
# Deleted: ../outputs/DIA_close_price.png
# Deleted: ../outputs/000001_RoA_comparison.png
# Deleted: ../outputs/VT_returns.png
# Deleted: ../outputs/AAPL_Free Cash Flow_comparison.png
# Deleted: ../outputs/VEVE_correlation_matrix.png
# Deleted: ../outputs/IEL_RoE_comparison.png
# Deleted: ../outputs/AGL GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/CSL GICS I.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/601211_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/0700_Net Income Margin_comparison.png
# Deleted: ../outputs/^AORD_dividends_and_change_over_time.png
# Deleted: ../outputs/0700_correlation_matrix.png
# Deleted: ../outputs/STW_key_ticker_stats_table.png
# Deleted: ../outputs/IEL GICS I.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/AAPL_close_price.png
# Deleted: ../outputs/CSL_P_B_comparison.png
# Deleted: ../outputs/VEVE_key_ticker_stats_table.png
# Deleted: ../outputs/CSL_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/CSL_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/VAS_close_price.png
# Deleted: ../outputs/VT_comparative_returns.png
# Deleted: ../outputs/IEL_Net Income Margin_comparison.png
# Deleted: ../outputs/QQQ_dividends_and_change_over_time.png
# Deleted: ../outputs/DPZ_Net Profit Margin_comparison.png
# Deleted: ../outputs/601211_key_ticker_stats_table.png
# Deleted: ../outputs/GLD_returns.png
# Deleted: ../outputs/NVX_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/TYR_RoE_comparison.png
# Deleted: ../outputs/^AXJO_WMean_returns.png
# Deleted: ../outputs/^AORD_dividends_over_time.png
# Deleted: ../outputs/IEL_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/601211_Free Cash Flow_comparison.png
# Deleted: ../outputs/TWE_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/000001_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVDA_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/TWE_RoA_comparison.png
# Deleted: ../outputs/CSL_RoE_comparison.png
# Deleted: ../outputs/IEL_P_E_comparison.png
# Deleted: ../outputs/^GSPC_returns.png
# Deleted: ../outputs/TYR_P_B_comparison.png
# Deleted: ../outputs/IEL_stock_splits_over_time.png
# Deleted: ../outputs/EFA_correlation_matrix.png
# Deleted: ../outputs/0700_close_price.png
# Deleted: ../outputs/TWE_interested_ticker_raw_stats.png
# Deleted: ../outputs/DPZ_RoA_comparison.png
# Deleted: ../outputs/^AORD_close_price.png
# Deleted: ../outputs/SPY_stock_splits_over_time.png
# Deleted: ../outputs/IEL_D_E_comparison.png
# Deleted: ../outputs/^AORD_key_ticker_stats_table.png
# Deleted: ../outputs/NVDA_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/0700_Free Cash Flow_comparison.png
# Deleted: ../outputs/TWE_dividends_and_change_over_time.png
# Deleted: ../outputs/IEL_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/AGL_returns.png
# Deleted: ../outputs/ACWI_returns.png
# Deleted: ../outputs/0700_Net Profit Margin_comparison.png
# Deleted: ../outputs/NVX_WMean_returns.png
# Deleted: ../outputs/NVDA_stock_splits_over_time.png
# Deleted: ../outputs/DPZ_comparative_returns.png
# Deleted: ../outputs/NVX_close_price.png
# Deleted: ../outputs/QQQ_stock_splits_over_time.png
# Deleted: ../outputs/GLD_correlation_matrix.png
# Deleted: ../outputs/VEVE_comparative_returns.png
# Deleted: ../outputs/VAS_correlation_matrix.png
# Deleted: ../outputs/CSL_dividends_over_time.png
# Deleted: ../outputs/VT_key_ticker_stats_table.png
# Deleted: ../outputs/IEL GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/TYR_P_E_comparison.png
# Deleted: ../outputs/IEL_P_B_comparison.png
# Deleted: ../outputs/NVX_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/TWE GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/CSL_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/VAS_dividends_and_change_over_time.png
# Deleted: ../outputs/000001_returns.png
# Deleted: ../outputs/TYR_WMean_returns.png
# Deleted: ../outputs/DPZ_Net Income Margin_comparison.png
# Deleted: ../outputs/TWE_stock_splits_over_time.png
# Deleted: ../outputs/IEL_WMean_returns.png
# Deleted: ../outputs/IEL_Net Profit Margin_comparison.png
# Deleted: ../outputs/TYR_D_E_comparison.png
# Deleted: ../outputs/TYR_interested_ticker_raw_stats.png
# Deleted: ../outputs/NVDA_Current Ratio_comparison.png
# Deleted: ../outputs/0700_RoA_comparison.png
# Deleted: ../outputs/TYR_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/AAPL_interested_ticker_raw_stats.png
# Deleted: ../outputs/AAPL_Net Profit Margin_comparison.png
# Deleted: ../outputs/AAPL_Current Ratio_comparison.png
# Deleted: ../outputs/AGL_Net Profit Margin_comparison.png
# Deleted: ../outputs/NVDA_Net Income Margin_comparison.png
# Deleted: ../outputs/TYR_Net Profit Margin_comparison.png
# Deleted: ../outputs/TYR GICS I.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/TYR_close_price.png
# Deleted: ../outputs/IEL_Current Ratio_comparison.png
# Deleted: ../outputs/TYR GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/DPZ_close_price.png
# Deleted: ../outputs/AGL_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/601211_Dividend Yield_comparison.png
# Deleted: ../outputs/IEL GICS I.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/601211_dividends_and_change_over_time.png
# Deleted: ../outputs/NVX_Current Ratio_comparison.png
# Deleted: ../outputs/STW_returns.png
# Deleted: ../outputs/CSL_correlation_matrix.png
# Deleted: ../outputs/NVX_RoA_comparison.png
# Deleted: ../outputs/VAS_stock_splits_over_time.png
# Deleted: ../outputs/NVX_returns.png
# Deleted: ../outputs/EFA_key_ticker_stats_table.png
# Deleted: ../outputs/CSL_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/000001_Net Income Margin_comparison.png
# Deleted: ../outputs/CSL_stock_splits_over_time.png
# Deleted: ../outputs/VAS_returns.png
# Deleted: ../outputs/GLD_key_ticker_stats_table.png
# Deleted: ../outputs/AGL_dividends_and_change_over_time.png
# Deleted: ../outputs/CSL_DPS_comparison.png
# Deleted: ../outputs/CSL GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/DPZ_stock_splits_over_time.png
# Deleted: ../outputs/^AXJO_stock_splits_over_time.png
# Deleted: ../outputs/601211_RoA_comparison.png
# Deleted: ../outputs/NVDA_returns.png
# Deleted: ../outputs/AAPL_returns.png
# Deleted: ../outputs/AAPL_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/VT_correlation_matrix.png
# Deleted: ../outputs/SPY_comparative_returns.png
# Deleted: ../outputs/STW_close_price.png
# Deleted: ../outputs/0700_Dividend Yield_comparison.png
# Deleted: ../outputs/VEVE.L_close_price.png
# Deleted: ../outputs/VEVE.L_stock_splits_over_time.png
# Deleted: ../outputs/IEL_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/ACWI_key_ticker_stats_table.png
# Deleted: ../outputs/TYR_DPS_comparison.png
# Deleted: ../outputs/IEL_dividends_and_change_over_time.png
# Deleted: ../outputs/AAPL_Dividend Yield_comparison.png
# Deleted: ../outputs/NVDA_Net Profit Margin_comparison.png
# Deleted: ../outputs/IEL_close_price.png
# Deleted: ../outputs/TYR_Net Income Margin_comparison.png
# Deleted: ../outputs/^AORD_comparative_returns.png
# Deleted: ../outputs/AGL_stock_splits_over_time.png
# Deleted: ../outputs/AAPL_Net Income Margin_comparison.png
# Deleted: ../outputs/TYR_Dividend Yield_comparison.png
# Deleted: ../outputs/CSL_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/NVX GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/AGL_Net Income Margin_comparison.png
# Deleted: ../outputs/AAPL_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/DIA_comparative_returns.png
# Deleted: ../outputs/IEL_Free Cash Flow_comparison.png
# Deleted: ../outputs/NVX_dividends_and_change_over_time.png
# Deleted: ../outputs/0700_dividends_and_change_over_time.png
# Deleted: ../outputs/^AORD_correlation_matrix.png
# Deleted: ../outputs/0700_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/NVDA_close_price.png
# Deleted: ../outputs/DPZ_correlation_matrix.png
# Deleted: ../outputs/0700_key_ticker_stats_table.png
# Deleted: ../outputs/VT_close_price.png
# Deleted: ../outputs/CSL_close_price.png
# Deleted: ../outputs/TYR_dividends_and_change_over_time.png
# Deleted: ../outputs/CSL GICS I.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/000001_Net Profit Margin_comparison.png
# Deleted: ../outputs/NVX_key_ticker_stats_table.png
# Deleted: ../outputs/AGL_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/000001_correlation_matrix.png
# Deleted: ../outputs/IEL_DPS_comparison.png
# Deleted: ../outputs/DPZ_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/CSL_comparative_returns.png
# Deleted: ../outputs/AGL_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/AAPL_stock_splits_over_time.png
# Deleted: ../outputs/NVX GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/^AXJO_correlation_matrix.png
# Deleted: ../outputs/AGL_Current Ratio_comparison.png
# Deleted: ../outputs/000001_dividends_and_change_over_time.png
# Deleted: ../outputs/ACWI_comparative_returns.png
# Deleted: ../outputs/TWE_WMean_returns.png
# Deleted: ../outputs/VEVE.L_correlation_matrix.png
# Deleted: ../outputs/DIA_returns.png
# Deleted: ../outputs/AGL_RoA_comparison.png
# Deleted: ../outputs/SPY_returns.png
# Deleted: ../outputs/TYR_key_ticker_stats_table.png
# Deleted: ../outputs/TYR GICS S.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/CSL_Dividend Yield_comparison.png
# Deleted: ../outputs/AGL_D_E_comparison.png
# Deleted: ../outputs/0700_interested_ticker_raw_stats.png
# Deleted: ../outputs/AGL_P_E_comparison.png
# Deleted: ../outputs/601211_Net Income Margin_comparison.png
# Deleted: ../outputs/601211_RoE_comparison.png
# Deleted: ../outputs/NVDA_key_ticker_stats_table.png
# Deleted: ../outputs/CSL_Net Income Margin_comparison.png
# Deleted: ../outputs/QQQ_key_ticker_stats_table.png
# Deleted: ../outputs/TWE_DPS_comparison.png
# Deleted: ../outputs/^HSI_returns.png
# Deleted: ../outputs/VT_stock_splits_over_time.png
# Deleted: ../outputs/NVDA_Free Cash Flow_comparison.png
# Deleted: ../outputs/TWE_comparative_returns.png
# Deleted: ../outputs/AGL_correlation_matrix.png
# Deleted: ../outputs/IEL_dividends_over_time.png
# Deleted: ../outputs/NVX_RoE_comparison.png
# Deleted: ../outputs/TWE_key_ticker_stats_table.png
# Deleted: ../outputs/TWE_Net Income Margin_comparison.png
# Deleted: ../outputs/EFA_returns.png
# Deleted: ../outputs/601211_correlation_matrix.png
# Deleted: ../outputs/601211_Interest Coverage Ratio_comparison.png
# Deleted: ../outputs/DPZ_DPS_comparison.png
# Deleted: ../outputs/NVX_correlation_matrix.png
# Deleted: ../outputs/TWE_Dividend Yield_comparison.png
# Deleted: ../outputs/TWE_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/ACWI_correlation_matrix.png
# Deleted: ../outputs/DIA_dividends_and_change_over_time.png
# Deleted: ../outputs/VEVE.L_dividends_and_change_over_time.png
# Deleted: ../outputs/AAPL_comparative_returns.png
# Deleted: ../outputs/AGL_P_B_comparison.png
# Deleted: ../outputs/SPY_close_price.png
# Deleted: ../outputs/NVX_Free Cash Flow_comparison.png
# Deleted: ../outputs/IEL_key_ticker_stats_table.png
# Deleted: ../outputs/0700_DPS_comparison.png
# Deleted: ../outputs/AAPL_dividends_and_change_over_time.png
# Deleted: ../outputs/SPY_key_ticker_stats_table.png
# Deleted: ../outputs/AGL_comparative_returns.png
# Deleted: ../outputs/CSL_WMean_returns.png
# Deleted: ../outputs/^AORD_stock_splits_over_time.png
# Deleted: ../outputs/CSL_Net Profit Margin_comparison.png
# Deleted: ../outputs/601211_P_E_comparison.png
# Deleted: ../outputs/QQQ_returns.png
# Deleted: ../outputs/AGL_RoE_comparison.png
# Deleted: ../outputs/NVDA_DPS_comparison.png
# Deleted: ../outputs/601211_Net Profit Margin_comparison.png
# Deleted: ../outputs/STW_stock_splits_over_time.png
# Deleted: ../outputs/NVX_dividends_over_time.png
# Deleted: ../outputs/IEL GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/TYR_returns.png
# Deleted: ../outputs/^AXJO_close_price.png
# Deleted: ../outputs/601211_D_E_comparison.png
# Deleted: ../outputs/EFA_dividends_and_change_over_time.png
# Deleted: ../outputs/AAPL_DPS_comparison.png
# Deleted: ../outputs/STW_dividends_and_change_over_time.png
# Deleted: ../outputs/QQQ_comparative_returns.png
# Deleted: ../outputs/0700_Current Ratio_comparison.png
# Deleted: ../outputs/^AXJO_dividends_over_time.png
# Deleted: ../outputs/NVX_P_E_comparison.png
# Deleted: ../outputs/TWE_Net Profit Margin_comparison.png
# Deleted: ../outputs/CSL_returns.png
# Deleted: ../outputs/TYR GICS I.WMean_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/AGL_close_price.png
# Deleted: ../outputs/601211_stock_splits_over_time.png
# Deleted: ../outputs/NVX_D_E_comparison.png
# Deleted: ../outputs/AAPL_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/000001_DPS_comparison.png
# Deleted: ../outputs/TWE_same_industry_tickers_mcap_table.png
# Deleted: ../outputs/SPY_dividends_and_change_over_time.png
# Deleted: ../outputs/IEL GICS S.WMean_interested_ticker_key_interested_stats_diff.png
# Deleted: ../outputs/TWE_returns.png
# Deleted: ../outputs/DPZ_Free Cash Flow_comparison.png
# Deleted: ../outputs/DIA_stock_splits_over_time.png
# Deleted: ../outputs/601211_P_B_comparison.png
# Deleted: ../outputs/QQQ_close_price.png
# Deleted: ../outputs/AGL_WMean_returns.png
# Deleted: ../outputs/000001_Dividend Yield_comparison.png
# Deleted: ../outputs/601211_Current Ratio_comparison.png
# Deleted: ../outputs/000001_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/AGL_Dividend Yield_comparison.png
# Deleted: ../outputs/EFA_comparative_returns.png
# Deleted: ../outputs/000001_key_ticker_stats_table.png
# Deleted: ../outputs/NVX_P_B_comparison.png
# Deleted: ../outputs/NVDA_interested_ticker_raw_stats.png
# Deleted: ../outputs/TYR_comparative_returns.png
# Deleted: ../outputs/601211_interested_ticker_raw_stats.png
# Deleted: ../outputs/DPZ_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/DPZ_interested_ticker_raw_stats.png
# Deleted: ../outputs/TYR GICS S.WMean_interested_ticker_key_interested_stats_pct_change.png
# Deleted: ../outputs/TYR_interested_ticker_key_interested_stats.png
# Deleted: ../outputs/NVX_interested_ticker_key_interested_stats.png
# All files in '../outputs' have been deleted.
